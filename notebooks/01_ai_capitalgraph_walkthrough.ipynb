# %% [markdown]
# # AI CapitalGraph: Reproducible Walkthrough
#
# This notebook runs the tested research pipeline, then inspects the company panel, correlation results, network metrics and explainable strategic-anomaly screen. It intentionally imports the reusable package instead of duplicating analysis logic.

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))
from aicapitalgraph.analysis import ProjectPaths, run_analysis

# %%
summary = run_analysis(ProjectPaths(ROOT))
summary

# %% [markdown]
# ## Association Results
#
# These are exploratory rank associations with a documented-evidence indicator. They do not identify causal effects or true adoption rates.

# %%
pd.read_csv(ROOT / 'results/correlation_results.csv')

# %% [markdown]
# ## Strategic Review Queue
#
# A high score prioritises source review. It is not a claim about intent, legality or competitive harm.

# %%
scores = pd.read_csv(ROOT / 'results/strategic_anomaly_scores.csv')
scores[['actor', 'target', 'relationship_type', 'anomaly_score', 'review_tier', 'alternative_explanation']]

# %% [markdown]
# ## Network Leaders

# %%
pd.read_csv(ROOT / 'results/network_metrics.csv').head(15)
